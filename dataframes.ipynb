# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Name': ['Rishi','kinjal','hardyansh','mohit'],
    'age' : [20,19,19,19],
    'city': ['jodhpur','chitorgarh','bikaner','paota'],
    'Salary': [100000,90000,50000,50000]
}
df = pd.DataFrame(data)
df
# Out:
#         Name  age        city  Salary
# 0      Rishi   20     jodhpur  100000
# 1     kinjal   19  chitorgarh   90000
# 2  hardyansh   19     bikaner   50000
# 3      mohit   19       paota   50000

# %%
data_list = [
    ['rishi',20,'Jodhpur',100000],
    ['kinjal',19,'chittorgarh',90000],
    ['hardyansh',19,'bikaner',60000],
    ['mohit',19,'paota',50000]
]   
df2 = pd.DataFrame (data_list)
columns = ["name","age","city","salary"]
df2 = pd.DataFrame(data_list,columns = columns)
df2
# Out:
#         name  age         city  salary
# 0      rishi   20      Jodhpur  100000
# 1     kinjal   19  chittorgarh   90000
# 2  hardyansh   19      bikaner   60000
# 3      mohit   19        paota   50000

# %%
df2.head()
# Out:
#            0   1            2       3
# 0      rishi  20      Jodhpur  100000
# 1     kinjal  19  chittorgarh   90000
# 2  hardyansh  19      bikaner   60000
# 3      mohit  19        paota   50000

# %%
df2.head(2)
# Out:
#         0   1            2       3
# 0   rishi  20      Jodhpur  100000
# 1  kinjal  19  chittorgarh   90000

# %%
df2.tail()
# Out:
#            0   1            2       3
# 0      rishi  20      Jodhpur  100000
# 1     kinjal  19  chittorgarh   90000
# 2  hardyansh  19      bikaner   60000
# 3      mohit  19        paota   50000

# %%
df2.tail(2)
# Out:
#            0   1        2      3
# 2  hardyansh  19  bikaner  60000
# 3      mohit  19    paota  50000

# %%
df.shape
# Out:
# (4, 4)

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df2.columns
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.columns.tolist()
# Out:
# ['Name', 'age', 'city', 'Salary']

# %%
df.columns
# Out:
# Index(['Name', 'age', 'city', 'Salary'], dtype='str')

# %%
df.dtypes
# Out:
# Name        str
# age       int64
# city        str
# Salary    int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      str
#  1   age     4 non-null      int64
#  2   city    4 non-null      str
#  3   Salary  4 non-null      int64
# dtypes: int64(2), str(2)
# memory usage: 260.0 bytes

# %%
df.describe()
# Out:
#          age         Salary
# count   4.00       4.000000
# mean   19.25   72500.000000
# std     0.50   26299.556397
# min    19.00   50000.000000
# 25%    19.00   50000.000000
# 50%    19.00   70000.000000
# 75%    19.25   92500.000000
# max    20.00  100000.000000

# %%
df['Name']
# Out:
# 0        Rishi
# 1       kinjal
# 2    hardyansh
# 3        mohit
# Name: Name, dtype: str

# %%
df[[Name,salary]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df[[Name,salary]]
#
# NameError: name 'Name' is not defined

# %%
df[['Name','Salary']]
# Out:
#         Name  Salary
# 0      Rishi  100000
# 1     kinjal   90000
# 2  hardyansh   50000
# 3      mohit   50000

# %%
selection and indexing of columns

# %%
df['Name']
# Out:
# 0        Rishi
# 1       kinjal
# 2    hardyansh
# 3        mohit
# Name: Name, dtype: str

# %%
df[['Name','city']]
# Out:
#         Name        city
# 0      Rishi     jodhpur
# 1     kinjal  chitorgarh
# 2  hardyansh     bikaner
# 3      mohit       paota

# %%
creating a new column
# Out:
#   Cell In[49], line 1
#     creating a new column
#              ^
# SyntaxError: invalid syntax

# %%
df["Designation"] = ['Ceo','cfo','cmo','coo']

# %%
df
# Out:
#         Name  age        city  Salary Designation
# 0      Rishi   20     jodhpur  100000         Ceo
# 1     kinjal   19  chitorgarh   90000         cfo
# 2  hardyansh   19     bikaner   50000         cmo
# 3      mohit   19       paota   50000         coo

# %%
remove a column

# %%
df.drop('age',axis=1)
# Out:
#         Name        city  Salary Designation
# 0      Rishi     jodhpur  100000         Ceo
# 1     kinjal  chitorgarh   90000         cfo
# 2  hardyansh     bikaner   50000         cmo
# 3      mohit       paota   50000         coo

# %%
df
# Out:
#         Name  age        city  Salary Designation
# 0      Rishi   20     jodhpur  100000         Ceo
# 1     kinjal   19  chitorgarh   90000         cfo
# 2  hardyansh   19     bikaner   50000         cmo
# 3      mohit   19       paota   50000         coo

# %%
df.drop(["city","age"],axis=1)
# Out:
#         Name  Salary Designation
# 0      Rishi  100000         Ceo
# 1     kinjal   90000         cfo
# 2  hardyansh   50000         cmo
# 3      mohit   50000         coo

# %%
df
# Out:
#         Name  age        city  Salary Designation
# 0      Rishi   20     jodhpur  100000         Ceo
# 1     kinjal   19  chitorgarh   90000         cfo
# 2  hardyansh   19     bikaner   50000         cmo
# 3      mohit   19       paota   50000         coo

# %%
df.drop(2,axis=0)
# Out:
#      Name  age        city  Salary Designation
# 0   Rishi   20     jodhpur  100000         Ceo
# 1  kinjal   19  chitorgarh   90000         cfo
# 3   mohit   19       paota   50000         coo

# %%
df.drop(3,axis=0)
# Out:
#         Name  age        city  Salary Designation
# 0      Rishi   20     jodhpur  100000         Ceo
# 1     kinjal   19  chitorgarh   90000         cfo
# 2  hardyansh   19     bikaner   50000         cmo

# %%
df.loc[[0,1]]
# Out:
#      Name  age        city  Salary Designation
# 0   Rishi   20     jodhpur  100000         Ceo
# 1  kinjal   19  chitorgarh   90000         cfo

# %%
df.iloc[0]
# Out:
# Name             Rishi
# age                 20
# city           jodhpur
# Salary          100000
# Designation        Ceo
# Name: 0, dtype: object

# %%
SELECTING SUBSET ROWS AND COLUMNS

# %%
df.loc[[0,1]][["city","Salary"]]
# Out:
#          city  Salary
# 0     jodhpur  100000
# 1  chitorgarh   90000

# %%
df.loc[[2,3]][["Name","age"]]
# Out:
#         Name  age
# 2  hardyansh   19
# 3      mohit   19

# %%
df
# Out:
#         Name  age        city  Salary Designation
# 0      Rishi   20     jodhpur  100000         Ceo
# 1     kinjal   19  chitorgarh   90000         cfo
# 2  hardyansh   19     bikaner   50000         cmo
# 3      mohit   19       paota   50000         coo

# %%
CONDITIONAL SELECTIONS

# %%
df[df["age"]>=20]
# Out:
#     Name  age     city  Salary Designation
# 0  Rishi   20  jodhpur  100000         Ceo

# %%
df2[(df2["age"] >= 19) & (df2["city"] == "Jodhpur")]
# Out:
#     name  age     city  salary
# 0  rishi   20  Jodhpur  100000

# %%
df
# Out:
#         Name  age        city  Salary Designation
# 0      Rishi   20     jodhpur  100000         Ceo
# 1     kinjal   19  chitorgarh   90000         cfo
# 2  hardyansh   19     bikaner   50000         cmo
# 3      mohit   19       paota   50000         coo
