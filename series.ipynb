# %%
import numpy as np
import pandas as pd

# %%
labels = ['a','b','c']
my_list = [10,20,30]
arr = np.array([10,20,30])
d = {1:10,2:20,3:30}

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_list,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64

# %%
marks = pd.Series([85,70,62,90])
print(marks)
# Out:
# 0    85
# 1    70
# 2    62
# 3    90
# dtype: int64

# %%
lab = ['os','dsa','it','pandas']

# %%
marks = pd.Series([98,90,96,96])
pd.series(marks,index=lab)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 2
#       1 marks = pd.Series([98,90,96,96])
# ----> 2 pd.series(marks,index=lab)
#
# AttributeError: module 'pandas' has no attribute 'series'

# %%
mark = ([10,20,30,40,])

# %%
pd.Series(mark,index= lab)
# Out:
# os        10
# dsa       20
# it        30
# pandas    40
# dtype: int64
