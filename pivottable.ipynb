# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    826     12   John  January      Q1
# 1  2023-01-02       B   West    678     34   Mary  January      Q1
# 2  2023-01-03       C  North    586     44    Bob  January      Q1
# 3  2023-01-04       D  South    663     26  Alice  January      Q1
# 4  2023-01-05       A   East    570     29   John  January      Q1
# 5  2023-01-06       B   West    178     73   Mary  January      Q1
# 6  2023-01-07       C  North    781     49    Bob  January      Q1
# 7  2023-01-08       D  South    626     61  Alice  January      Q1
# 8  2023-01-09       A   East    896     38   John  January      Q1
# 9  2023-01-10       B   West    629     89   Mary  January      Q1
# 10 2023-01-11       C  North    385     60    Bob  January      Q1
# 11 2023-01-12       D  South    905     56  Alice  January      Q1
# 12 2023-01-13       A   East    487     61   John  January      Q1
# 13 2023-01-14       B   West    684     11   Mary  January      Q1
# 14 2023-01-15       C  North    915     93    Bob  January      Q1
# 15 2023-01-16       D  South    356     76  Alice  January      Q1
# 16 2023-01-17       A   East    892     54   John  January      Q1
# 17 2023-01-18       B   West    463     58   Mary  January      Q1
# 18 2023-01-19       C  North    888     73    Bob  January      Q1
# 19 2023-01-20       D  South    390     82  Alice  January      Q1

# %%
pd.pivot_table(df,values="Sales",index="Region",columns="Product",aggfunc="sum")
# Out:
# Product       A       B       C       D
# Region
# East     3671.0     NaN     NaN     NaN
# North       NaN     NaN  3555.0     NaN
# South       NaN     NaN     NaN  2940.0
# West        NaN  2632.0     NaN     NaN

# %%
piv = pd.pivot_table(df,values=["Sales","Units"], index="Region",columns="Product")
piv
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     734.2    NaN    NaN    NaN  38.8   NaN   NaN   NaN
# North      NaN    NaN  711.0    NaN   NaN   NaN  63.8   NaN
# South      NaN    NaN    NaN  588.0   NaN   NaN   NaN  60.2
# West       NaN  526.4    NaN    NaN   NaN  53.0   NaN   NaN

# %%
CROSS TABS

# %%
cross tabs is used for couting purpose and pivot table is used for aggregation purpose

# %%
cro = pd.crosstab(df["Region"],df['Product'])

# %%
cro
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
